# %%
def model_result_plot(train_pred, y_train, test_pred, y_test):
    # посмотрим, как модель вела себя на тренировочном отрезке ряда
    
    plt.figure(figsize=(15, 5))
    plt.plot(train_pred, label="prediction")
    plt.plot(y_train, label = 'y_train')
    plt.axis('tight')
    plt.grid(True)
    plt.legend()

    # запоминаем ошибку на трейне
    scale = 1
    deviation = mean_absolute_error(train_pred, y_train)
    # и на тестовом
    
    lower = test_pred-scale*deviation
    upper = test_pred+scale*deviation

    Anomalies = np.array([np.NaN]*len(test_pred))
    Anomalies[y_test<lower] = y_test[y_test<lower]

    plt.figure(figsize=(15, 5))
    plt.plot(test_pred, label="prediction")
    #plt.plot(lower, "r--", label="upper bond / lower bond")
    #plt.plot(upper, "r--")
    plt.plot(y_test, label="y_test")
    #plt.plot(Anomalies, "ro", markersize=10)
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Mean absolute error {}".format(mean_absolute_error(test_pred, y_test)))#round()
    plt.grid(True)
    plt.legend()

# %% [markdown]
# Ошибка - mae

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
from statsmodels.tsa.statespace.sarimax import SARIMAX
import traceback
import itertools
import statsmodels.api as sm

# %% [markdown]
# - Экспоненциальное сглаживание
# - ARIMA, SARIMA
# - Garch
#
# ##### Динамические линейные модели
#
# Динамические линейные модели представляют другой класс моделей предсказания временных рядов (рис. 14). Идея заключается в том, что в каждый момент времени tt эти модели соответствуют линейной модели, но коэффициент регрессии постоянно меняется.
# Пример динамической линейной модели ниже:
#
# y(t)=⍺(t)+tβ(t)+w(t)y(t)=⍺(t)+tβ(t)+w(t),
# ⍺(t)=⍺(t−1)+m(t)⍺(t)=⍺(t−1)+m(t),
# β(t)=β(t−1)+r(t)β(t)=β(t−1)+r(t),
# w(t)w(t) ~ N(0,W)N(0,W), m(t)m(t) ~ N(0,M)N(0,M), r(t)r(t) ~ N(0,R)N(0,R).
# - TBATS
# - Prophet
# - NNETAR

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
import warnings
warnings.filterwarnings("ignore")
# %run libs/libs.py

import prediction as p
config = "C:/Users/msson/energy_artefacts/conf/gisee_test.json.example"
engine = db.db_connect(config)
# Out:
# The configuration file has been loaded.

# %% [markdown]
# Получим данные:

# %%
timeseries_water, timeseries_el, timeseries_heat = get_data(engine)
# Out:
# PREPARING DATA
# first date for which data are available:           2018-08-20T00:00:00.000000000
# total number of days for which there is data:      465
# The last date on which the training is conducted:  2019-05-12T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2017-06-01T00:00:00.000000000
# total number of days for which there is data:      910
# The last date on which the training is conducted:  2019-05-12T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-30T00:00:00.000000000
# total number of days for which there is data:      762
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-31T00:00:00.000000000
# total number of days for which there is data:      761
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-29T00:00:00.000000000
# total number of days for which there is data:      763
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-11-27T00:00:00.000000000
# total number of days for which there is data:      734
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-08-31T00:00:00.000000000
# total number of days for which there is data:      822
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-25T00:00:00.000000000
# total number of days for which there is data:      767
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-11-06T00:00:00.000000000
# total number of days for which there is data:      755
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-25T00:00:00.000000000
# total number of days for which there is data:      767
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-25T00:00:00.000000000
# total number of days for which there is data:      767
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-12-10T00:00:00.000000000
# total number of days for which there is data:      721
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-25T00:00:00.000000000
# total number of days for which there is data:      767
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-09-03T00:00:00.000000000
# total number of days for which there is data:      806
# The last date on which the training is conducted:  2020-05-01T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-08-29T00:00:00.000000000
# total number of days for which there is data:      824
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-08-27T00:00:00.000000000
# total number of days for which there is data:      826
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-08-24T00:00:00.000000000
# total number of days for which there is data:      829
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-09-03T00:00:00.000000000
# total number of days for which there is data:      819
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-11-30T00:00:00.000000000
# total number of days for which there is data:      731
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-10T00:00:00.000000000
# total number of days for which there is data:      782
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-12T00:00:00.000000000
# total number of days for which there is data:      780
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-12T00:00:00.000000000
# total number of days for which there is data:      780
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-12T00:00:00.000000000
# total number of days for which there is data:      780
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-14T00:00:00.000000000
# total number of days for which there is data:      778
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-12T00:00:00.000000000
# total number of days for which there is data:      780
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-12-10T00:00:00.000000000
# total number of days for which there is data:      721
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-12-11T00:00:00.000000000
# total number of days for which there is data:      720
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-09-28T00:00:00.000000000
# total number of days for which there is data:      794
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-12-19T00:00:00.000000000
# total number of days for which there is data:      712
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-12-18T00:00:00.000000000
# total number of days for which there is data:      713
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-12-20T00:00:00.000000000
# total number of days for which there is data:      711
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-12-20T00:00:00.000000000
# total number of days for which there is data:      711
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-12-18T00:00:00.000000000
# total number of days for which there is data:      713
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-12-21T00:00:00.000000000
# total number of days for which there is data:      710
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2010-05-13T00:00:00.000000000
# total number of days for which there is data:      3034
# The last date on which the training is conducted:  2018-02-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-06-07T00:00:00.000000000
# total number of days for which there is data:      907
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-08-20T00:00:00.000000000
# total number of days for which there is data:      464
# The last date on which the training is conducted:  2019-05-11T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-19T00:00:00.000000000
# total number of days for which there is data:      773
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-03T00:00:00.000000000
# total number of days for which there is data:      789
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-02T00:00:00.000000000
# total number of days for which there is data:      790
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-02T00:00:00.000000000
# total number of days for which there is data:      790
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-17T00:00:00.000000000
# total number of days for which there is data:      775
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-04T00:00:00.000000000
# total number of days for which there is data:      788
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-04T00:00:00.000000000
# total number of days for which there is data:      625
# The last date on which the training is conducted:  2019-12-03T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-17T00:00:00.000000000
# total number of days for which there is data:      775
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-09-04T00:00:00.000000000
# total number of days for which there is data:      818
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-10-30T00:00:00.000000000
# total number of days for which there is data:      762
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-09-03T00:00:00.000000000
# total number of days for which there is data:      819
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-09-03T00:00:00.000000000
# total number of days for which there is data:      819
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-11-28T00:00:00.000000000
# total number of days for which there is data:      733
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-11-29T00:00:00.000000000
# total number of days for which there is data:      732
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000
# PREPARING DATA
# first date for which data are available:           2018-11-30T00:00:00.000000000
# total number of days for which there is data:      731
# The last date on which the training is conducted:  2020-05-14T00:00:00.000000000

# %%
#df = timeseries_el[0]['2014-01-01':]
df = timeseries_water[10][:-135]
tsplot_only(np.array(df.ec_d))

# %%
X_y = get_features(df, engine)#[:-100]

# %%
#y_train, y_test = timeseries_water[1][:-100], timeseries_water[1][-100:]

# %%
X_y_train_features, X_y_test_features =  X_y[:-200], X_y[-200:] 

y_train, y_test = X_y_train_features.ec_d, X_y_test_features.ec_d
X_train = X_y_train_features.drop('ec_d', axis = 1)
X_test = X_y_test_features.drop('ec_d', axis = 1)

# %% [markdown]
# Выбор признаков

# %%
all_features = ['is_holiday', 'temperature', 'sun_time', 'weekday', 'temperaturelag1', 'temperaturelag2',
       'temperaturelag3',  'heat_off']
# 'temperaturelag4', 'temperaturelag5', 'temperaturelag6','is_holidaylag1', 'is_holidaylag2', 'is_holidaylag3', 'is_holidaylag4', 'is_holidaylag5', 'is_holidaylag6', 
# 'sun_timelag1', 'sun_timelag2', 'sun_timelag3','sun_timelag4', 'sun_timelag5', 'sun_timelag6', 

selected_features = ['temperature', 'sun_time', 'weekday', 'is_holiday']
selected_features = all_features

# %%
selected_features = select_features(X_y, engine, max_features = 10, target = "ec_d")
# Out:
# 626
# 626
# 626
# 626
# [{'temperature': 113, 'sun_time': 105, 'temperaturelag2': 52, 'temperaturelag6': 48, 'temperaturelag3': 41, 'temperaturelag5': 40, 'temperaturelag1': 39, 'temperaturelag4': 38, 'weekday': 23, 'sun_timelag6': 22}, {'ec_d': 1.0, 'sun_time': 0.26734030225920435, 'sun_timelag1': 0.2659335083647714, 'sun_timelag2': 0.264432104689264, 'sun_timelag3': 0.26283178359497644, 'sun_timelag4': 0.26113506973619366, 'sun_timelag5': 0.2593424973986737, 'sun_timelag6': 0.2574556938550264, 'is_holiday': 0.25679966235719387, 'temperaturelag1': 0.20765820889794992}, {'is_holiday': 1, 'sun_time': 1, 'weekday': 1, 'temperaturelag1': 1, 'temperaturelag4': 1, 'temperaturelag6': 1}]

# %%
selected_features
# Out:
# array(['is_holiday', 'sun_time', 'weekday', 'temperaturelag1',
#        'temperaturelag4', 'temperaturelag6', 'sun_timelag6'], dtype=object)

# %%
selected_features = ['temperature', 'sun_time', 'weekday', 'is_holiday']

# %% [markdown]
# ### SARIMAX
# Перебор гиперпараметров: p = d = q = range(0, 2)

# %%
def fit_sarimax(X_train, X_test, y_train, y_test):
    print("FITTING SARIMAX")

    p = d = q = range(0, 2)
    pdq = [(x[0], 1,  2) for x in list(itertools.product(p))]#,7
    seasonal_pdq = [(x[0], 1, 1, 7) for x in list(itertools.product(p))]
    res = []

    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        for param in pdq:
            for param_seasonal in seasonal_pdq:
                try:
                    print(param)
                    mod = sm.tsa.statespace.SARIMAX(y_train,
                                                    order=param,
                                                    exog=X_train,
                                                    seasonal_order=param_seasonal,
                                                    enforce_stationarity=False,
                                                    enforce_invertibility=False)

                    results = mod.fit(disp=False)


                    #pred = results.get_prediction(start=pd.to_datetime(X_train[-100:].index.min()), 

                     #                             end=X_train[-100:].index.max(), 
                      #                            exog=X_train[-100:],
                      #                            dynamic=False, 
                      #                            full_results=True)
                    pred = results.get_prediction(end=results.nobs + len(X_test) - 1, exog = X_test)

                    y_pred = pred.predicted_mean
                    y_obs  = y_test#[-100:]


                    mse  = ((y_pred - y_obs) ** 2).mean()
                    rmse = math.sqrt(mse)
                    cv   = 100 * rmse / y_obs.mean()
                    mape = 100 *((y_pred - y_obs)/y_obs).abs().mean()

                    res.append([param, param_seasonal, results.aic, cv, mape, mse, rmse, results])

                except Exception as e:
                    print('SARIMAX:\n', traceback.format_exc())
                    continue
    return(res)

# %%
models = fit_sarimax(X_train[selected_features], X_test[selected_features], y_train, y_test)
model = models[0][-1]
# Out:
# FITTING SARIMAX
# (0, 1, 2)
# (0, 1, 2)
# (1, 1, 2)
# (1, 1, 2)

# %%
train_pred = model.get_prediction(end=model.nobs - 1).predicted_mean
test_pred = model.get_prediction(end=model.nobs + len(X_test) - 1, exog = X_test[selected_features]).predicted_mean[-len(X_test):]

# %%
model_result_plot(train_pred, y_train, test_pred, y_test)

# %% [markdown]
# ### Динамические линейные модели

# %%
from fbprophet import Prophet

# %% [markdown]
# #### Prophet
#
# Prophet считает, что временной ряд может быть разложен следующим образом:
#
# y(t)=g(t)+s(t)+h(t)+ε(t),
#
# g(t) — тренд,
#
# s(t) — сезонность,
#
# h(t) — каникулы, т.е аномальные данные,
#
# ε(t) — ошибки.
#
# Отобранные неавторегрессионные признаки добавляем в модель как регрессор.
#
# 1) переделаем датафрейм для prophet

# %%
X_y_train_features_prophet = X_y_train_features.rename(columns={'ec_d': "y" })
X_y_train_features_prophet = X_y_train_features_prophet.reset_index()
X_y_train_features_prophet = X_y_train_features_prophet.rename(columns={'index': "ds" })

X_y_train_features_prophet = X_y_train_features.rename(columns={'ec_d': "y" })
X_y_train_features_prophet = X_y_train_features_prophet.reset_index()
X_y_train_features_prophet = X_y_train_features_prophet.rename(columns={'index': "ds" })

# %%
X_y_test_features_prophet = X_y_test_features.reset_index()
X_y_test_features_prophet = X_y_test_features_prophet.rename(columns={'index': "ds" })

# %% [markdown]
# 2) получим отобранные признаки и добавим их как регрессор

# %%
selected_features = ['temperature', 'sun_time', 'weekday', 'is_holiday']

# %%
m = Prophet()
for feature in selected_features:
    m.add_regressor(feature, prior_scale=0.5, mode='multiplicative')
m.yearly_seasonality = True
m.weekly_seasonality = True
#m.add_seasonality(name="quaterly", period = 365.25/4, fourier_order=1, prior_scale = 15)
#m.add_seasonality(name="yearly", period = 365.25, fourier_order=2, prior_scale = 30)
m.fit(X_y_train_features_prophet)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
test_pred = m.predict(X_y_test_features_prophet)
train_pred = m.predict(X_y_train_features_prophet)

# %%
model_result_plot(train_pred.yhat.values, y_train.values, test_pred.yhat.values, y_test.values)

# %% [markdown]
# Средняя ошибка

# %%
mean_absolute_error(pred.yhat, X_y_test_features_prophet.ec_d)
# Out:
# 1977.4306018177588

# %% [markdown]
# Стандартные модели машинного обучения
# XGBoost

# %%
def model_plot(model, x_train, x_test):
    

    # посмотрим, как модель вела себя на тренировочном отрезке ряда
    prediction_train = model.predict(x_train)
    plt.figure(figsize=(15, 5))
    plt.plot(prediction_train)
    plt.plot(y_train)
    plt.axis('tight')
    plt.grid(True)
    # запоминаем ошибку на трейне
    deviation = mean_absolute_error(prediction_train.yhat, X_y_test_features_prophet.ec_d)
    # и на тестовом
    prediction_test = model.predict(dtest)
    lower = prediction_test-scale*deviation
    upper = prediction_test+scale*deviation

    Anomalies = np.array([np.NaN]*len(y_test))
    Anomalies[y_test<lower] = y_test[y_test<lower]

    plt.figure(figsize=(15, 5))
    plt.plot(prediction_test, label="prediction")
    plt.plot(lower, "r--", label="upper bond / lower bond")
    plt.plot(upper, "r--")
    plt.plot(list(y_test), label="y_test")
    plt.plot(Anomalies, "ro", markersize=10)
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("XGBoost Mean absolute error {} users".format(round(mean_absolute_error(prediction_test, y_test))))
    plt.grid(True)
    plt.legend()

# %%
import xgboost as xgb

def XGB_forecast(X_train, X_test, y_train, y_test , test_size=0.15, scale=1.96):#data

    # исходные данные
    #X_train, X_test, y_train, y_test = train_test_split(data,  test_size)
    #print(X_train)
    #print(X_test)
    dtrain = xgb.DMatrix(X_train, label=y_train)
    
    dtest = xgb.DMatrix(X_test)

    # задаём параметры
    params = {
        'objective': 'reg:squarederror',#'objective': 'reg:linear',
        'booster':'gbtree'#'booster':'gblinear'
    }
    trees = 100

    # прогоняем на кросс-валидации с метрикой rmse
    cv = xgb.cv(params, dtrain, metrics = ('rmse'), verbose_eval=False, nfold=10, show_stdv=False, num_boost_round=trees)

    # обучаем xgboost с оптимальным числом деревьев, подобранным на кросс-валидации
    bst = xgb.train(params, dtrain, num_boost_round=cv['test-rmse-mean'].argmin())
    
    # запоминаем ошибку на кросс-валидации
    deviation = cv.loc[cv['test-rmse-mean'].argmin()]["test-rmse-mean"]
    print('deviation', deviation)
    
    # посмотрим, как модель вела себя на тренировочном отрезке ряда
    prediction_train = bst.predict(dtrain)
    '''plt.figure(figsize=(15, 5))
    plt.plot(prediction_train)
    plt.plot(y_train)
    plt.axis('tight')
    plt.grid(True)
    '''
    prediction_test = []
    pred = y_train.values[-1]
    
    if ('lag1' in X_test.columns):
        for ind, row in X_test.iterrows():
            ww = []
            for i in row.values:
                ww.append(i)
            cols = []
            for i in X_test.columns.values:
                cols.append(i)
            pdtest = pd.DataFrame([ww], columns = cols)
            pdtest['lag1'] = pred
            dtest = xgb.DMatrix(pdtest)
            pred = bst.predict(dtest)
            prediction_test.append(pred[0])
    else:
        prediction_test = bst.predict(dtest)
    # и на тестовом
    #
    lower = prediction_test-scale*deviation
    upper = prediction_test+scale*deviation
    #print(y_test)
    #print(lower)
    Anomalies = np.array([np.NaN]*len(y_test))
    Anomalies[y_test<lower] = y_test[y_test<lower]
    '''
    plt.figure(figsize=(15, 5))
    plt.plot(prediction_test, label="prediction")
    plt.plot(lower, "r--", label="upper bond / lower bond")
    plt.plot(upper, "r--")
    plt.plot(list(y_test), label="y_test")
    plt.plot(Anomalies, "ro", markersize=10)
    plt.legend(loc="best")
    plt.axis('tight')
    #print(prediction_test, y_test)
    plt.title("XGBoost Mean absolute error {} ".format(round(mean_absolute_error(prediction_test, y_test))))
    plt.grid(True)
    plt.legend()'''
    model_result_plot(prediction_train, y_train.values, prediction_test, y_test.values)

# %%
X_y_xgb[-1:].ec_d.values[0]
# Out:
# 1150.9613083999996

# %%
selected_features = ['temperature', 'sun_time', 'weekday', 'is_holiday', 'ec_d', 'heat_off']#, 'lag1'
selected_features = all_features

# %%
X_y_xgb = df
X_y_xgb = get_features(X_y_xgb, engine, lags = True)
X_y_xgb = X_y_xgb[selected_features]

# %% [markdown]
# Если добавлять lag1

# %%
XGB_forecast(X_train, X_test, y_train, y_test)
# Out:
# deviation 81.28314789999999

# %% [markdown]
# Если не добавлять lag1

# %%
XGB_forecast(X_train, X_test, y_train, y_test)
# Out:
# deviation 81.28314789999999

# %%
from tbats import TBATS, BATS
# Fit the model
estimator = TBATS(seasonal_periods=(365, 7))#7, , 90, 30
model = estimator.fit(y_train)
# Forecast 365 days ahead
#y_forecast = model.forecast(steps=365)

# %%
test_pred = model.forecast(steps=365)

# %%
model_result_plot(y_train.values, y_train.values, test_pred[:len(y_test)], y_test.values)

# %% [markdown]
# Сравнение с автомл

# %%
from lightautoml.automl.base import AutoML
from lightautoml.ml_algo.boost_lgbm import BoostLGBM
from lightautoml.ml_algo.tuning.optuna import OptunaTuner
from lightautoml.pipelines.features.lgb_pipeline import LGBSimpleFeatures
from lightautoml.pipelines.ml.base import MLPipeline
from lightautoml.pipelines.selection.importance_based import ImportanceCutoffSelector, ModelBasedImportanceEstimator
from lightautoml.reader.base import PandasToPandasReader
from lightautoml.tasks import Task
from lightautoml.utils.profiler import Profiler
from lightautoml.automl.blend import WeightedBlender

# %%
N_THREADS = 8 # threads cnt for lgbm and linear models
N_FOLDS = 5 # folds cnt for AutoML
RANDOM_STATE = 42 # fixed random state for various reasons
TEST_SIZE = 0.2 # Test size for metric check
TARGET_NAME = 'TARGET' # Target column name

# %%
X_y_train_features, X_y_test_features =  X_y[:-200], X_y[-200:] 

y_train, y_test = X_y_train_features.ec_d, X_y_test_features.ec_d
X_train = X_y_train_features.drop('ec_d', axis = 1)
X_test = X_y_test_features.drop('ec_d', axis = 1)

# %%
import pandas as pd
from sklearn.metrics import f1_score
from lightautoml.automl.presets.tabular_presets import TabularAutoML
from lightautoml.tasks import Task

#df_train, df_test = pd.read_csv('../input/titanic/train.csv'), pd.read_csv('../input/titanic/test.csv')

automl = TabularAutoML(task = Task('binary', metric = lambda y_true, y_pred: f1_score(y_true, (y_pred > 0.5)*1)))
oof_pred = automl.fit_predict(X_y_train_features,  roles = {'target': 'ec_d'})#, 'drop': ['PassengerId']
test_pred = automl.predict(X_y_test_features)

pd.DataFrame({'PassengerId':df_test.PassengerId, 'Survived': (test_pred.data[:, 0] > 0.5)*1}).to_csv('submit.csv', index = False)
# Out:
# Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# Start automl preset with listed constraints:
# - time: 3600 seconds
# - cpus: 4 cores
# - memory: 16 gb
#
# Train data shape: (426, 24)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-501-e73690800a3d> in <module>
#       7
#       8 automl = TabularAutoML(task = Task('binary', metric = lambda y_true, y_pred: f1_score(y_true, (y_pred > 0.5)*1)))
# ----> 9 oof_pred = automl.fit_predict(X_y_train_features,  roles = {'target': 'ec_d'})#, 'drop': ['PassengerId']
#      10 test_pred = automl.predict(X_y_test_features)
#      11
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\automl\presets\tabular_presets.py in fit_predict(self, train_data, roles, train_features, cv_iter, valid_data, valid_features)
#     413             data, _ = read_data(valid_data, valid_features, self.cpu_limit, self.read_csv_params)
#     414
# --> 415         oof_pred = super().fit_predict(train, roles=roles, cv_iter=cv_iter, valid_data=valid_data)
#     416
#     417         return cast(NumpyDataset, oof_pred)
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\automl\presets\base.py in fit_predict(self, train_data, roles, train_features, cv_iter, valid_data, valid_features)
#     174         logger.info('- memory: {} gb\n'.format(self.memory_limit))
#     175         self.timer.start()
# --> 176         result = super().fit_predict(train_data, roles, train_features, cv_iter, valid_data, valid_features)
#     177         logger.info('\nAutoml preset training completed in {:.2f} seconds.'.format(self.timer.time_spent))
#     178
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\automl\base.py in fit_predict(self, train_data, roles, train_features, cv_iter, valid_data, valid_features)
#     157         """
#     158         self.timer.start()
# --> 159         train_dataset = self.reader.fit_read(train_data, train_features, roles)
#     160
#     161         assert len(self._levels) <= 1 or train_dataset.folds is not None, \
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\reader\base.py in fit_read(self, train_data, features_names, roles, **kwargs)
#     302
#     303         folds = set_sklearn_folds(self.task, kwargs['target'].values, cv=self.cv, random_state=self.random_state,
# --> 304                                   group=None if 'group' not in kwargs else kwargs['group'])
#     305         if folds is not None:
#     306             kwargs['folds'] = Series(folds, index=train_data.index)
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\reader\utils.py in set_sklearn_folds(task, target, cv, random_state, group)
#      37
#      38         folds = np.zeros(target.shape[0], dtype=np.int32)
# ---> 39         for n, (f0, f1) in enumerate(split):
#      40             folds[f1] = n
#      41
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#     330                 .format(self.n_splits, n_samples))
#     331
# --> 332         for train, test in super().split(X, y, groups):
#     333             yield train, test
#     334
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#      78         X, y, groups = indexable(X, y, groups)
#      79         indices = np.arange(_num_samples(X))
# ---> 80         for test_index in self._iter_test_masks(X, y, groups):
#      81             train_index = indices[np.logical_not(test_index)]
#      82             test_index = indices[test_index]
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_split.py in _iter_test_masks(self, X, y, groups)
#     691
#     692     def _iter_test_masks(self, X, y=None, groups=None):
# --> 693         test_folds = self._make_test_folds(X, y)
#     694         for i in range(self.n_splits):
#     695             yield test_folds == i
#
# ~\AppData\Roaming\Python\Python37\site-packages\sklearn\model_selection\_split.py in _make_test_folds(self, X, y)
#     662             raise ValueError("n_splits=%d cannot be greater than the"
#     663                              " number of members in each class."
# --> 664                              % (self.n_splits))
#     665         if self.n_splits > min_groups:
#     666             warnings.warn(("The least populated class in y has only %d"
#
# ValueError: n_splits=5 cannot be greater than the number of members in each class.

# %%
# Standard python libraries
import os
import time
import re

# Installed libraries
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
import torch

# Imports from our package
from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
from lightautoml.dataset.roles import DatetimeRole
from lightautoml.tasks import Task
from lightautoml.utils.profiler import Profiler

# %%
N_THREADS = 4 # threads cnt for lightautoml
RANDOM_STATE = 42 # fixed random state for various reasons
TIMEOUT = 6 * 3600 # Time in seconds for automl run

# %%
np.random.seed(RANDOM_STATE)
torch.set_num_threads(N_THREADS)

# %%
# %%time
def rmse(y_true, y_pred, **kwargs):
    return mean_squared_error(y_true, y_pred, squared = False, **kwargs)

task = Task('reg')
# Out:
# Wall time: 6.48 ms

# %%
# %%time

roles = {
    'target': 'ec_d',
    #'drop': ['id'],
}
# Out:
# Wall time: 0 ns

# %%
# %%time 

automl = TabularUtilizedAutoML(task = task, 
                               timeout = TIMEOUT,
                               cpu_limit = N_THREADS,
                               reader_params = {'n_jobs': N_THREADS},
                               general_params = {'use_algos': [['linear_l2', 'lgb', 'lgb_tuned']]}, # Use only linear models and LGBM and no CatBoost
                               tuning_params = {'max_tuning_time': 25 * 60}, # Set 25 minutes for LGBM params tuning
                               lgb_params = {'default_params': {'num_trees': 100000, 'learning_rate': 0.005, 'early_stopping_rounds': 1000}, # Set smaller LR and more ES rounds
                                             'freeze_defaults': True},
                              )
# Out:
# Wall time: 28.9 ms

# %%
roles
# Out:
# {'target': 'ec_d'}

# %%
oof_pred = automl.fit_predict(X_y_train_features, roles = roles)
# Out:
# Current random state: {'reader_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# Found reader_params in kwargs, need to combine
# Merged variant for reader_params = {'n_jobs': 4, 'random_state': 42}
# Found general_params in kwargs, need to combine
# Merged variant for general_params = {'use_algos': [['linear_l2', 'lgb', 'lgb_tuned']], 'return_all_predictions': False}
# Start automl preset with listed constraints:
# - time: 21599.99103498459 seconds
# - cpus: 4 cores
# - memory: 16 gb
#
# Train data shape: (426, 24)
# Feats was rejected during automatic roles guess: []
#
#
# Layer 1 ...
# Train process start. Time left 21599.151607513428 secs
# Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -7949.982628845485
# Linear model: C = 5e-05 score = -7336.854534973992
# Linear model: C = 0.0001 score = -6926.823948914457
# Linear model: C = 0.0005 score = -6056.710580124054
# Linear model: C = 0.001 score = -5901.865547808159
# Linear model: C = 0.005 score = -5946.430401559397
# Linear model: C = 0.01 score = -6015.429772612408
#
# ===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -10489.96947565671
# Linear model: C = 5e-05 score = -9728.745736139394
# Linear model: C = 0.0001 score = -9190.053234631292
# Linear model: C = 0.0005 score = -8002.649480430415
# Linear model: C = 0.001 score = -7732.769125144723
# Linear model: C = 0.005 score = -7683.352996038611
# Linear model: C = 0.01 score = -7786.515545267549
# Linear model: C = 0.05 score = -7996.415124758585
#
# ===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -9390.829389736924
# Linear model: C = 5e-05 score = -8923.816479484252
# Linear model: C = 0.0001 score = -8647.620590463966
# Linear model: C = 0.0005 score = -8235.953209136793
# Linear model: C = 0.001 score = -8210.033695744958
# Linear model: C = 0.005 score = -8361.418394991219
# Linear model: C = 0.01 score = -8489.835308730395
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -10401.132113036141
# Linear model: C = 5e-05 score = -9887.184921046972
# Linear model: C = 0.0001 score = -9565.628967189854
# Linear model: C = 0.0005 score = -9021.898119308731
# Linear model: C = 0.001 score = -8959.69805312138
# Linear model: C = 0.005 score = -9108.440292727437
# Linear model: C = 0.01 score = -9265.635943513344
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -10099.722155204912
# Linear model: C = 5e-05 score = -9625.55093521783
# Linear model: C = 0.0001 score = -9330.05176676003
# Linear model: C = 0.0005 score = -8844.89081639311
# Linear model: C = 0.001 score = -8789.477518451695
# Linear model: C = 0.005 score = -8827.997651909618
# Linear model: C = 0.01 score = -8878.337156445301
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 21593.952694892883
# Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
#
# ===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
#
# Training until validation scores don't improve for 1000 rounds
# [100]	valid's l2: 6730.11
# [200]	valid's l2: 6015.43
# [300]	valid's l2: 5624.1
# [400]	valid's l2: 5413.87
# [500]	valid's l2: 5290.26
# [600]	valid's l2: 5209.94
# [700]	valid's l2: 5153.13
# [800]	valid's l2: 5130.29
# [900]	valid's l2: 5087.2
# [1000]	valid's l2: 5059.84
# [1100]	valid's l2: 5045.43
# [1200]	valid's l2: 5006.83
# [1300]	valid's l2: 4998.65
# [1400]	valid's l2: 4977.81
# [1500]	valid's l2: 4972.66
# [1600]	valid's l2: 4938.39
# [1700]	valid's l2: 4915.28
# [1800]	valid's l2: 4906.04
# [1900]	valid's l2: 4904.05
# [2000]	valid's l2: 4880.21
# [2100]	valid's l2: 4868.77
# [2200]	valid's l2: 4848.52
# [2300]	valid's l2: 4839.99
# [2400]	valid's l2: 4832.68
# [2500]	valid's l2: 4818.17
# [2600]	valid's l2: 4803.32
# [2700]	valid's l2: 4776.05
# [2800]	valid's l2: 4758.42
# [2900]	valid's l2: 4741.73
# [3000]	valid's l2: 4734.72
# [3100]	valid's l2: 4720.99
# [3200]	valid's l2: 4719.3
# [3300]	valid's l2: 4710.61
# [3400]	valid's l2: 4691.52
# [3500]	valid's l2: 4677.9
# [3600]	valid's l2: 4670.8
# [3700]	valid's l2: 4659.18
# [3800]	valid's l2: 4658.03
# [3900]	valid's l2: 4652.9
# [4000]	valid's l2: 4646.97
# [4100]	valid's l2: 4636.97
# [4200]	valid's l2: 4638.58
# [4300]	valid's l2: 4627.77
# [4400]	valid's l2: 4614.71
# [4500]	valid's l2: 4611.85
# [4600]	valid's l2: 4604.04
# [4700]	valid's l2: 4604.05
# [4800]	valid's l2: 4595.19
# [4900]	valid's l2: 4606.12
# [5000]	valid's l2: 4599.12
# [5100]	valid's l2: 4593.59
# [5200]	valid's l2: 4584.99
# [5300]	valid's l2: 4583.75
# [5400]	valid's l2: 4578.67
# [5500]	valid's l2: 4575.73
# [5600]	valid's l2: 4582.01
# [5700]	valid's l2: 4573.75
# [5800]	valid's l2: 4568.15
# [5900]	valid's l2: 4562.99
# [6000]	valid's l2: 4562.53
# [6100]	valid's l2: 4564.19
# [6200]	valid's l2: 4566.8
# [6300]	valid's l2: 4568.05
# [2500]	valid's l2: 4841.12
# [2600]	valid's l2: 4820.11
# [2700]	valid's l2: 4793.9
# [2800]	valid's l2: 4782.48
# [2900]	valid's l2: 4768.1
# [3000]	valid's l2: 4765.91
# [3100]	valid's l2: 4750.42
# [3200]	valid's l2: 4735.56
# [3300]	valid's l2: 4741.62
# [3400]	valid's l2: 4730.53
# [3500]	valid's l2: 4719.61
# [3600]	valid's l2: 4705.6
# [3700]	valid's l2: 4691.97
# [3800]	valid's l2: 4688.96
# [3900]	valid's l2: 4680
# [4000]	valid's l2: 4680.45
# [4100]	valid's l2: 4670.4
# [4200]	valid's l2: 4668.96
# [4300]	valid's l2: 4657.17
# [4400]	valid's l2: 4649.25
# [4500]	valid's l2: 4648.21
# [4600]	valid's l2: 4638.02
# [4700]	valid's l2: 4636.27
# [4800]	valid's l2: 4624.81
# [4900]	valid's l2: 4633.91
# [5000]	valid's l2: 4622.73
# [5100]	valid's l2: 4620.17
# [5200]	valid's l2: 4609.76
# [5300]	valid's l2: 4605.92
# [5400]	valid's l2: 4605.53
# [5500]	valid's l2: 4604.38
# [5600]	valid's l2: 4609.58
# [5700]	valid's l2: 4601.01
# [5800]	valid's l2: 4591.29
# ...
#
# ===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -9789.147955308537
# Linear model: C = 5e-05 score = -9103.012380997734
# Linear model: C = 0.0001 score = -8627.1431452122
# Linear model: C = 0.0005 score = -7576.301170426206
# Linear model: C = 0.001 score = -7335.8832862046875
# Linear model: C = 0.005 score = -7325.8968268707995
# Linear model: C = 0.01 score = -7450.855279850057
# Linear model: C = 0.05 score = -7664.7001065756895
#
# ===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
#
# Linear model: C = 1e-05 score = -7338.483008489143
# Linear model: C = 5e-05 score = -6747.716577550207
# Linear model: C = 0.0001 score = -6387.101682423047
# Linear model: C = 0.0005 score = -5704.243750797848
# Linear model: C = 0.001 score = -5547.455277724816
# Linear model: C = 0.005 score = -5439.396123221794
# Linear model: C = 0.01 score = -5466.083520038066
# Linear model: C = 0.05 score = -5527.266268091075
# Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# Time left 19778.19390130043
# Start fitting Selector_LightGBM ...
#
# ===== Start working with fold 0 for Selector_LightGBM =====
#
# Training until validation scores don't improve for 1000 rounds
# [100]	valid's l2: 8896.19
# [200]	valid's l2: 7994.46
# [300]	valid's l2: 7530.01
# [400]	valid's l2: 7276.79
# [500]	valid's l2: 7096.62
# [600]	valid's l2: 6973.1
# [700]	valid's l2: 6890.77
# [800]	valid's l2: 6810.17
# [900]	valid's l2: 6767.21
# [1000]	valid's l2: 6712.52
# [1100]	valid's l2: 6700.08
# [1200]	valid's l2: 6649.4
# [1300]	valid's l2: 6594.37
# [1400]	valid's l2: 6567.92
# [1500]	valid's l2: 6536.7
# [1600]	valid's l2: 6520.47
# [1700]	valid's l2: 6490.07
# [1800]	valid's l2: 6463.33
# [1900]	valid's l2: 6441.88
# [2000]	valid's l2: 6409.72
# [2100]	valid's l2: 6388.69
# [2200]	valid's l2: 6368.37
# [2300]	valid's l2: 6350.46
# [2400]	valid's l2: 6320.92
# [2500]	valid's l2: 6296.36
# [2600]	valid's l2: 6283.02
# [2700]	valid's l2: 6252.03
# [2800]	valid's l2: 6243.46
# [2900]	valid's l2: 6239.14
# [3000]	valid's l2: 6223.38
# [3100]	valid's l2: 6221.78
# [3200]	valid's l2: 6206.72
# [3300]	valid's l2: 6214.99
# [3400]	valid's l2: 6209.17
# [3500]	valid's l2: 6210.9
# [3600]	valid's l2: 6199.92
# [3700]	valid's l2: 6214.05
# [3800]	valid's l2: 6220.6
# [3900]	valid's l2: 6212.6
# [4000]	valid's l2: 6199.02
# [4100]	valid's l2: 6201.66
# [4200]	valid's l2: 6199.39
# [4300]	valid's l2: 6197.56
# [4400]	valid's l2: 6189.5
# [4500]	valid's l2: 6193.36
# [4600]	valid's l2: 6179.44
# [4700]	valid's l2: 6196.36
# [4800]	valid's l2: 6198.95
# [4900]	valid's l2: 6190.95
# [5000]	valid's l2: 6183.31
# [5100]	valid's l2: 6180.58
# [5200]	valid's l2: 6180.53
# [5300]	valid's l2: 6178.94
# [5400]	valid's l2: 6181.05
# [5500]	valid's l2: 6183.2
# [5600]	valid's l2: 6186.6
# [5700]	valid's l2: 6187.04
# [5800]	valid's l2: 6189.29
# [5900]	valid's l2: 6192.46
# [6000]	valid's l2: 6202.3
# [6100]	valid's l2: 6209.1
# [6200]	valid's l2: 6199.08
# [6300]	valid's l2: 6197.02
# Early stopping, best iteration is:
# [5325]	valid's l2: 6173.96
# Selector_LightGBM fitting and predicting completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-516-1e315a413f72> in <module>
# ----> 1 oof_pred = automl.fit_predict(X_y_train_features, roles = roles)
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\addons\utilization\utilization.py in fit_predict(self, train_data, roles, train_features, cv_iter, valid_data, valid_features)
#     277
#     278                 val_pred = automl.fit_predict(train_data, roles, train_features, cv_iter,
# --> 279                                               valid_data, valid_features)
#     280
#     281                 amls[n_cfg].append(MLPipeForAutoMLWrapper.from_automl(automl))
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\automl\presets\tabular_presets.py in fit_predict(self, train_data, roles, train_features, cv_iter, valid_data, valid_features)
#     413             data, _ = read_data(valid_data, valid_features, self.cpu_limit, self.read_csv_params)
#     414
# --> 415         oof_pred = super().fit_predict(train, roles=roles, cv_iter=cv_iter, valid_data=valid_data)
#     416
#     417         return cast(NumpyDataset, oof_pred)
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\automl\presets\base.py in fit_predict(self, train_data, roles, train_features, cv_iter, valid_data, valid_features)
#     174         logger.info('- memory: {} gb\n'.format(self.memory_limit))
#     175         self.timer.start()
# --> 176         result = super().fit_predict(train_data, roles, train_features, cv_iter, valid_data, valid_features)
#     177         logger.info('\nAutoml preset training completed in {:.2f} seconds.'.format(self.timer.time_spent))
#     178
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\automl\base.py in fit_predict(self, train_data, roles, train_features, cv_iter, valid_data, valid_features)
#     189             for k, ml_pipe in enumerate(level):
#     190
# --> 191                 pipe_pred = ml_pipe.fit_predict(train_valid)
#     192                 level_predictions.append(pipe_pred)
#     193                 pipes.append(ml_pipe)
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\pipelines\ml\base.py in fit_predict(self, train_valid)
#     115
#     116         # apply features pipeline
# --> 117         train_valid = train_valid.apply_feature_pipeline(self.features_pipeline)
#     118
#     119         # train and apply post selection
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\validation\base.py in apply_feature_pipeline(self, features_pipeline)
#      73         """
#      74         train_valid = copy(self)
# ---> 75         train_valid.train = features_pipeline.fit_transform(train_valid.train)
#      76         return train_valid
#      77
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\pipelines\features\base.py in fit_transform(self, train)
#      99         self._pipeline = self._merge_seq(train) if self.sequential else self._merge(train)
#     100
# --> 101         return self._pipeline.fit_transform(train)
#     102
#     103     def transform(self, test: LAMLDataset) -> LAMLDataset:
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\transformers\base.py in fit_transform(self, dataset)
#     275         """
#     276         if self.n_jobs == 1:
# --> 277             res = self._fit_transform_singleproc(dataset)
#     278         else:
#     279             res = self._fit_transform_multiproc(dataset)
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\transformers\base.py in _fit_transform_singleproc(self, dataset)
#     237         for n in range(len(self.transformer_list)):
#     238             trf = self.transformer_list[n]
# --> 239             ds = trf.fit_transform(dataset)
#     240             if ds is not None:
#     241                 fnames.append(trf.features)
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\transformers\base.py in fit_transform(self, dataset)
#     150         """
#     151         for trf in self.transformer_list:
# --> 152             dataset = trf.fit_transform(dataset)
#     153
#     154         self.features = self.transformer_list[-1].features
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\transformers\base.py in fit_transform(self, dataset)
#     150         """
#     151         for trf in self.transformer_list:
# --> 152             dataset = trf.fit_transform(dataset)
#     153
#     154         self.features = self.transformer_list[-1].features
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\transformers\base.py in fit_transform(self, dataset)
#      95             check_func(dataset)
#      96
# ---> 97         return self.transform(dataset)
#      98
#      99
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\transformers\base.py in transform(self, dataset)
#     377                 all((x == y for (x, y) in zip(self.keys, dataset.features))):
#     378             return dataset
# --> 379         return dataset[:, self.keys]
#     380
#     381
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\dataset\base.py in __getitem__(self, k)
#     141             data = self._get_rows(data, rows)
#     142
# --> 143         dataset.set_data(data, features, roles)
#     144
#     145         return dataset
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\dataset\np_pd_dataset.py in set_data(self, data, features, roles)
#     517         """
#     518         super().set_data(data, features, roles)
# --> 519         self._check_dtype()
#     520
#     521     def _check_dtype(self):
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\dataset\np_pd_dataset.py in _check_dtype(self)
#     530                 self.dtypes[f] = self.roles[f].dtype
#     531
# --> 532         self.data = self.data.astype(self.dtypes)
#     533         self.data.reset_index(drop=True, inplace=True)
#     534         # do we need to reset_index ?? If yes - drop for Series attrs too
#
# ~\Anaconda3\envs\stan_env\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5886         result.columns = self.columns
#    5887         return result
# -> 5888
#    5889     @final
#    5890     def copy(self: FrameOrSeries, deep: bool_t = True) -> FrameOrSeries:
#
# ~\Anaconda3\envs\stan_env\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     253       letter  number
#     254     0      a       1
# --> 255     1      b       2
#     256     0      c       3
#     257     1      d       4
#
# ~\Anaconda3\envs\stan_env\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     302     """
#     303     Orchestrates a concatenation operation for BlockManagers
# --> 304     """
#     305
#     306     def __init__(
#
# ValueError: No objects to concatenate

# %%
print('oof_pred:\n{}\nShape = {}'.format(oof_pred[:10], oof_pred.shape))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-513-9c473d657d4d> in <module>
# ----> 1 print('oof_pred:\n{}\nShape = {}'.format(oof_pred[:10], oof_pred.shape))
#
# NameError: name 'oof_pred' is not defined

# %%
# %%time

test_pred = automl.predict(X_y_test_features, n_jobs = N_THREADS)
print('Prediction for test data:\n{}\nShape = {}'.format(test_pred[:10], test_pred.shape))

print('Check scores...')
print('OOF score: {}'.format(rmse(train_data['target'].values, oof_pred.data[:, 0])))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <timed exec> in <module>
#
# ~\AppData\Roaming\Python\Python37\site-packages\log_calls\log_calls.py in _deco_base_f_wrapper_(*args, **kwargs)
#    1937                 # (_xxx variables set, ok to call f)
#    1938                 if not _enabled:
# -> 1939                     ret = f(*args, **kwargs)
#    1940                     self._logging_state_pop(enabled_too=True)
#    1941                     return ret
#
# ~\AppData\Roaming\Python\Python37\site-packages\lightautoml\addons\utilization\utilization.py in predict(self, data, features_names, return_all_predictions, **kwargs)
#     351         outer_preds = []
#     352
# --> 353         for amls_pipe in self.outer_pipes:
#     354
#     355             inner_preds = []
#
# AttributeError: 'TabularUtilizedAutoML' object has no attribute 'outer_pipes'

# %%
import pip
installed_packages = pip.get_installed_distributions()
installed_packages_list = sorted(["%s==%s" % (i.key, i.version)
     for i in installed_packages])
print(installed_packages_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-518-1f7a06abc3d2> in <module>
#       1 import pip
# ----> 2 installed_packages = pip.get_installed_distributions()
#       3 installed_packages_list = sorted(["%s==%s" % (i.key, i.version)
#       4      for i in installed_packages])
#       5 print(installed_packages_list)
#
# AttributeError: module 'pip' has no attribute 'get_installed_distributions'
